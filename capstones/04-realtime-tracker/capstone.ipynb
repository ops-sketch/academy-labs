# %% [markdown]
# # Capstone 4: Real-Time Satellite Tracker
#
# **Track:** Mission GIS Engineer — earns the *Certified Mission GIS Engineer* credential.
# **Full brief + rubric:** [https://launchdetect.com/academy/capstone/4/](https://launchdetect.com/academy/capstone/4/)
#
# ---
#
# _Cesium globe + live ISS/Starlink + visible passes + 24h replay._

# %% [markdown]
# ## Why this capstone matters
#
# Track 4 capstone synthesizes the web + 3D + real-time toolkit. Why a satellite tracker specifically? Because it's the canonical real-time spatial app — your users want to know 'where is the ISS right now', 'when will Starlink overfly me', 'show me a live view'. Solving this teaches the pattern for every real-time GIS app.

# %% [markdown]
# ## Brief
#
# Build a Cesium-based web application that shows real-time positions of the ISS and a configurable Starlink shell on a 3D globe. The user supplies a latitude/longitude; the app shows the next 5 visible passes (elevation > 30°) at that location. Click any satellite to inspect orbital elements (TLE epoch, inclination, mean motion, period). A time slider lets the user replay the last 24 hours of positions.

# %% [markdown]
# ## Rubric — your output must satisfy ALL of these
#
# - Cesium globe loads and renders without console errors
# - ISS position updates at ≥1 Hz with no visible stuttering
# - Visible-pass calculation matches a reference (e.g. n2yo.com) within 30 seconds
# - Click-to-inspect popup shows all required orbital elements correctly
# - Time-slider replay covers 24 hours and animates smoothly
# - Code is deployable as a static site (no backend required)

# %% [markdown]
# ## Setup
#
# Install dependencies (Colab):

# %%
# !pip install -q leafmap[common] requests websockets

# %% [markdown]
# ## Implementation
#
# Build your solution below. The capstone is intentionally open-ended — there is no single right answer, only outputs that meet the rubric. Aim for:
#
# - Clear separation between data loading, processing, and output
# - Verifiable claims (don't say 'detected' — show the brightness temperature, location, time)
# - Reproducible runs from a clean checkout

# %%
# Real-Time Satellite Tracker — starting scaffold

# TODO: implement
raise NotImplementedError("Build the capstone deliverable. Reference the rubric on the capstone page.")

# %% [markdown]
# ## Deliverable
#
# **Required:** Static web app (HTML+JS+CSS) deployable to GitHub Pages or S3, plus a 2-minute demo video
#
# **Submission path:** push your finished capstone to a public GitHub repo of your own, then visit [https://launchdetect.com/academy/verify/](https://launchdetect.com/academy/verify/) to register your submission for certificate review (requires LaunchDetect Gold).
#
# ---
#
# Dataset for this capstone: [https://github.com/launchdetect/academy-labs/tree/main/capstones/04-realtime-tracker](https://github.com/launchdetect/academy-labs/tree/main/capstones/04-realtime-tracker)
