# %% [markdown]
# # Capstone 1: Global Launch Site Atlas
#
# **Track:** Ground Station Operator — earns the *Certified Ground Station Operator* credential.
# **Full brief + rubric:** [https://launchdetect.com/academy/capstone/1/](https://launchdetect.com/academy/capstone/1/)
#
# ---
#
# _Map every active orbital launch pad on Earth._

# %% [markdown]
# ## Why this capstone matters
#
# This is the synthesis of Track 1. Everything from coordinate systems through QGIS print layouts gets exercised on a real, citation-grade deliverable. Why a launch-site atlas specifically? Because it's the foundation that every subsequent capstone references — Capstones 2-5 all need to know where launch pads are. Build it right once; use it for the rest of your career.

# %% [markdown]
# ## Brief
#
# Build a GeoJSON FeatureCollection of all currently-active orbital launch pads worldwide (~20 sites). Each feature has properties: name, country (ISO 3166), operator, status (active/proposed/retired), vehicles flown, first orbital launch year, latest orbital launch year, latitude, longitude. Style the layer in QGIS by operator and country. Compose a publication-quality print layout: title, legend, scale bar, north arrow, attribution. Export the final map as a PDF at A2 size.

# %% [markdown]
# ## Rubric — your output must satisfy ALL of these
#
# - GeoJSON contains ≥18 active orbital launch pads with all required properties populated
# - Property values are correct and citable (UN Office for Outer Space Affairs / launch-provider primary sources)
# - Coordinate precision is at least 4 decimal places for latitude/longitude
# - QGIS layout includes title, legend, scale bar, north arrow, data-source attribution
# - PDF is publication-quality (300 dpi, no overlapping labels)

# %% [markdown]
# ## Setup
#
# Install dependencies (Colab):

# %%
# !pip install -q leafmap[common] pyproj geopandas shapely

# %% [markdown]
# ## Implementation
#
# Build your solution below. The capstone is intentionally open-ended — there is no single right answer, only outputs that meet the rubric. Aim for:
#
# - Clear separation between data loading, processing, and output
# - Verifiable claims (don't say 'detected' — show the brightness temperature, location, time)
# - Reproducible runs from a clean checkout

# %%
# Global Launch Site Atlas — starting scaffold

# TODO: implement
raise NotImplementedError("Build the capstone deliverable. Reference the rubric on the capstone page.")

# %% [markdown]
# ## Deliverable
#
# **Required:** launch-sites.geojson + atlas.pdf, both committed to your personal GitHub fork of academy-labs
#
# **Submission path:** push your finished capstone to a public GitHub repo of your own, then visit [https://launchdetect.com/academy/verify/](https://launchdetect.com/academy/verify/) to register your submission for certificate review (requires LaunchDetect Gold).
#
# ---
#
# Dataset for this capstone: [https://github.com/launchdetect/academy-labs/tree/main/capstones/01-launch-site-atlas](https://github.com/launchdetect/academy-labs/tree/main/capstones/01-launch-site-atlas)
