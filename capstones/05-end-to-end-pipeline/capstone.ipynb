# %% [markdown]
# # Capstone 5: End-to-End Detection Pipeline
#
# **Track:** Space GIS Architect — earns the *Certified Space GIS Architect* credential.
# **Full brief + rubric:** [https://launchdetect.com/academy/capstone/5/](https://launchdetect.com/academy/capstone/5/)
#
# ---
#
# _Raw NetCDF → georeferenced detections → PostGIS → REST → 3D globe._

# %% [markdown]
# ## Brief
#
# Build a complete production-grade space-GIS pipeline: ingest 10 frames of GOES-18 ABI Band 7 NetCDF from the NOAA AWS Open Data bucket; georeference each frame (parallax-corrected); threshold-detect hotspots; cluster hotspot pixels across consecutive frames into plume tracks; score each track for confidence (geometric coherence, brightness consistency, motion); persist results to PostGIS with proper indexes; expose a FastAPI /detections REST endpoint with bbox, time-range, and confidence filters; render results live on a Cesium globe served from the same FastAPI app. Deliverable is a public GitHub repository + a 5-minute video walking through the pipeline.

# %% [markdown]
# ## Rubric — your output must satisfy ALL of these
#
# - Pipeline runs end-to-end on the provided 10-frame test dataset
# - Detections match the known launch ground truth within 5 km and 30 seconds
# - False-positive rate < 10% on the test dataset
# - PostGIS schema includes appropriate GIST indexes for spatial and time queries
# - REST API is documented via OpenAPI, all endpoints respond within 200 ms
# - Cesium globe renders detections with hover-popups
# - GitHub repo is public with clear README, setup instructions, license
# - 5-minute video clearly explains architecture decisions

# %% [markdown]
# ## Setup
#
# Install dependencies (Colab):

# %%
# !pip install -q xarray rasterio numpy torch pystac-client pyproj boto3 fastapi

# %% [markdown]
# ## Implementation
#
# Build your solution below. The capstone is intentionally open-ended — there is no single right answer, only outputs that meet the rubric. Aim for:
#
# - Clear separation between data loading, processing, and output
# - Verifiable claims (don't say 'detected' — show the brightness temperature, location, time)
# - Reproducible runs from a clean checkout

# %%
# End-to-End Detection Pipeline — starting scaffold

# TODO: implement
raise NotImplementedError("Build the capstone deliverable. Reference the rubric on the capstone page.")

# %% [markdown]
# ## Deliverable
#
# **Required:** Public GitHub repo (Python + JavaScript) + 5-minute video on YouTube/Vimeo + signed-off README
#
# **Submission path:** push your finished capstone to a public GitHub repo of your own, then visit [https://launchdetect.com/academy/verify/](https://launchdetect.com/academy/verify/) to register your submission for certificate review (requires LaunchDetect Gold).
#
# ---
#
# Dataset for this capstone: [https://github.com/launchdetect/academy-labs/tree/main/capstones/05-end-to-end-pipeline](https://github.com/launchdetect/academy-labs/tree/main/capstones/05-end-to-end-pipeline)
