# %% [markdown]
# # Capstone 2: Ground-Track Coverage Tool
#
# **Track:** Orbital Analyst — earns the *Certified Orbital Analyst* credential.
# **Full brief + rubric:** [https://launchdetect.com/academy/capstone/2/](https://launchdetect.com/academy/capstone/2/)
#
# ---
#
# _Given any TLE, produce ground track + coverage + country-overflight table._

# %% [markdown]
# ## Why this capstone matters
#
# Track 2 capstone: orbital mechanics + spatial analysis combined into a tool that solves real operational questions. Why ground-track + coverage + country dwell? Because those three answers — *where it goes, how much it sees, under whose law* — drive every real mission-planning decision in the satellite operations business. Master this and you can run a constellation mission planner.

# %% [markdown]
# ## Brief
#
# Build a Python tool that, given any TLE as input, outputs (1) the 24-hour ground track as a GeoJSON LineString with timestamped vertices, (2) a coverage polygon assuming a 1000-km swath sensor, (3) a country-overflight table listing each country overflown with total dwell time in seconds. The country mapping must use the Natural Earth admin-0 boundary dataset (provided). Visualize the ground track on a Folium map, color-coded by altitude.

# %% [markdown]
# ## Rubric — your output must satisfy ALL of these
#
# - Tool runs from CLI: `python coverage_tool.py --tle path/to/tle.txt`
# - Ground track GeoJSON is correctly geodesic (no straight-line shortcuts across the pole)
# - Country dwell table is consistent with the ground track (per-country dwell ≤ total propagation time)
# - Coverage polygon area is consistent with 1000-km swath × ground-track length
# - Folium HTML map renders correctly with altitude-colored ground track

# %% [markdown]
# ## Setup
#
# Install dependencies (Colab):

# %%
# !pip install -q leafmap[common] skyfield geopandas shapely

# %% [markdown]
# ## Implementation
#
# Build your solution below. The capstone is intentionally open-ended — there is no single right answer, only outputs that meet the rubric. Aim for:
#
# - Clear separation between data loading, processing, and output
# - Verifiable claims (don't say 'detected' — show the brightness temperature, location, time)
# - Reproducible runs from a clean checkout

# %%
# Ground-Track Coverage Tool — starting scaffold

# TODO: implement
raise NotImplementedError("Build the capstone deliverable. Reference the rubric on the capstone page.")

# %% [markdown]
# ## Deliverable
#
# **Required:** Python project (CLI + library) + sample outputs for ISS, Hubble, and a Starlink satellite
#
# **Submission path:** push your finished capstone to a public GitHub repo of your own, then visit [https://launchdetect.com/academy/verify/](https://launchdetect.com/academy/verify/) to register your submission for certificate review (requires LaunchDetect Gold).
#
# ---
#
# Dataset for this capstone: [https://github.com/launchdetect/academy-labs/tree/main/capstones/02-coverage-tool](https://github.com/launchdetect/academy-labs/tree/main/capstones/02-coverage-tool)
