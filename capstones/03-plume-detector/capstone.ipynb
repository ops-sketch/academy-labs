# %% [markdown]
# # Capstone 3: Thermal Plume Detector
#
# **Track:** Remote Sensing Specialist — earns the *Certified Remote Sensing Specialist* credential.
# **Full brief + rubric:** [https://launchdetect.com/academy/capstone/3/](https://launchdetect.com/academy/capstone/3/)
#
# ---
#
# _Detect a real rocket plume from a real NOAA GOES NetCDF._

# %% [markdown]
# ## Why this capstone matters
#
# Track 3 capstone is the heart of LaunchDetect itself. You're building a working plume detector that operates on real NOAA GOES NetCDFs — the same data, same physics, same threshold logic powering the production pipeline. Why does this matter? Because by the end of this capstone you can answer 'how does LaunchDetect work' with a working implementation, not a description.

# %% [markdown]
# ## Brief
#
# Build a Python tool that, given a GOES-18 ABI Band 7 NetCDF file and a known launch event (date, location, vehicle), outputs detection records `(timestamp_UTC, lat, lon, brightness_temp_K, area_km²)` for each detected plume pixel cluster. Apply parallax correction. Apply false-positive filtering (mask known wildfires from the FIRMS dataset). Produce a Folium heatmap visualization showing detected hotspots overlaid on a basemap, with hover-popups showing the (t, T_b) for each detection.

# %% [markdown]
# ## Rubric — your output must satisfy ALL of these
#
# - Tool runs on the provided sample NetCDF and produces ≥1 valid plume detection record for the known launch
# - Detection timestamps are within 30 seconds of ignition time published by the launch operator
# - Coordinates are within 5 km of the known launch pad (after parallax correction)
# - Brightness temperatures are physically plausible (> 320 K for plume, > 290 K for background)
# - False-positive filtering rejects ≥90% of FIRMS-overlapping pixels in the same scene
# - Folium heatmap is interactive and correctly rendered

# %% [markdown]
# ## Setup
#
# Install dependencies (Colab):

# %%
# !pip install -q leafmap[common] xarray rasterio netCDF4 satpy

# %% [markdown]
# ## Implementation
#
# Build your solution below. The capstone is intentionally open-ended — there is no single right answer, only outputs that meet the rubric. Aim for:
#
# - Clear separation between data loading, processing, and output
# - Verifiable claims (don't say 'detected' — show the brightness temperature, location, time)
# - Reproducible runs from a clean checkout

# %%
# Thermal Plume Detector — starting scaffold

# TODO: implement
raise NotImplementedError("Build the capstone deliverable. Reference the rubric on the capstone page.")

# %% [markdown]
# ## Deliverable
#
# **Required:** Python tool + Jupyter notebook walkthrough + Folium HTML output for the test event
#
# **Submission path:** push your finished capstone to a public GitHub repo of your own, then visit [https://launchdetect.com/academy/verify/](https://launchdetect.com/academy/verify/) to register your submission for certificate review (requires LaunchDetect Gold).
#
# ---
#
# Dataset for this capstone: [https://github.com/launchdetect/academy-labs/tree/main/capstones/03-plume-detector](https://github.com/launchdetect/academy-labs/tree/main/capstones/03-plume-detector)
